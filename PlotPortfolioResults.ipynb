# %%
from matplotlib import pyplot as plt
import numpy as np
import sys
sys.path.append('./Tools')
# from  Port_Opt_MaxGeneration import SolvePortOpt_MaxGen_LCOE_Iterator, PreparePotOptInputs
from GeneralGeoTools import PlotEfficientFrontier, PlotTurbineLocations, PlotPowerTechDistribution

# %% [markdown]
# # Wind Only BOEM

# %%
SolutionPaths=[]
MainPortResultsPath="./OutputData/Portfolios/"

#1.2GW Transmission
SolutionPaths.append(MainPortResultsPath+"Wind_BOEM_Upscale24h_0.02Degree_GenCost_ATB_8MW_2020_Vestas_Transmission_1200MW.npz")
SolutionPaths.append(MainPortResultsPath+"Wind_BOEM_Upscale24h_0.02Degree_GenCost_ATB_12MW_2030_Transmission_1200MW.npz")
SolutionPaths.append(MainPortResultsPath+"Wind_BOEM_Upscale24h_0.02Degree_GenCost_ATB_15MW_2030_Transmission_1200MW.npz")
SolutionPaths.append(MainPortResultsPath+"Wind_BOEM_Upscale24h_0.02Degree_GenCost_ATB_18MW_2030_Transmission_1200MW.npz")

#1.0GW Transmission
SolutionPaths.append(MainPortResultsPath+"Wind_BOEM_Upscale24h_0.02Degree_GenCost_ATB_8MW_2020_Vestas_Transmission_1000MW.npz")
SolutionPaths.append(MainPortResultsPath+"Wind_BOEM_Upscale24h_0.02Degree_GenCost_ATB_12MW_2030_Transmission_1000MW.npz")
SolutionPaths.append(MainPortResultsPath+"Wind_BOEM_Upscale24h_0.02Degree_GenCost_ATB_15MW_2030_Transmission_1000MW.npz")
SolutionPaths.append(MainPortResultsPath+"Wind_BOEM_Upscale24h_0.02Degree_GenCost_ATB_18MW_2030_Transmission_1000MW.npz")

#0.6GW Transmission
SolutionPaths.append(MainPortResultsPath+"Wind_BOEM_Upscale24h_0.02Degree_GenCost_ATB_8MW_2020_Vestas_Transmission_600MW.npz")
SolutionPaths.append(MainPortResultsPath+"Wind_BOEM_Upscale24h_0.02Degree_GenCost_ATB_12MW_2030_Transmission_600MW.npz")
SolutionPaths.append(MainPortResultsPath+"Wind_BOEM_Upscale24h_0.02Degree_GenCost_ATB_15MW_2030_Transmission_600MW.npz")
SolutionPaths.append(MainPortResultsPath+"Wind_BOEM_Upscale24h_0.02Degree_GenCost_ATB_18MW_2030_Transmission_600MW.npz")

# #0.3GW Transmission
SolutionPaths.append(MainPortResultsPath+"Wind_BOEM_Upscale24h_0.02Degree_GenCost_ATB_8MW_2020_Vestas_Transmission_300MW.npz")
SolutionPaths.append(MainPortResultsPath+"Wind_BOEM_Upscale24h_0.02Degree_GenCost_ATB_12MW_2030_Transmission_300MW.npz")
SolutionPaths.append(MainPortResultsPath+"Wind_BOEM_Upscale24h_0.02Degree_GenCost_ATB_15MW_2030_Transmission_300MW.npz")
SolutionPaths.append(MainPortResultsPath+"Wind_BOEM_Upscale24h_0.02Degree_GenCost_ATB_18MW_2030_Transmission_300MW.npz")

Legend=["1.2GW TL - 8MW WT","1.2GW TL - 12MW WT","1.2GW TL - 15MW WT","1.2GW TL - 18MW WT",
        "1.0GW TL - 8MW WT","1.0GW TL - 12MW WT","1.0GW TL - 15MW WT","1.0GW TL - 18MW WT",
        "0.6GW TL - 8MW WT","0.6GW TL - 12MW WT","0.6GW TL - 15MW WT","0.6GW TL - 18MW WT",
        "0.3GW TL - 8MW WT","0.3GW TL - 12MW WT","0.3GW TL - 15MW WT","0.3GW TL - 18MW WT"]

Title="Wind BOEM portfolios"

SavePath="./OutputData/Plots/Portfolios/WindOnly/BOEM_WindOnly_EfficientFrontier.png"
PlotEfficientFrontier(SolutionPaths, Legend, Title, SavePath=SavePath)

# %%
MainPortResultsPath="./OutputData/Portfolios/"
SolutionPath=[]
SolutionPath.append(MainPortResultsPath+"Wind_BOEM_Upscale24h_0.02Degree_GenCost_ATB_18MW_2030_Transmission_1200MW.npz")
SolutionPath.append(MainPortResultsPath+"Wind_BOEM_Upscale24h_0.02Degree_GenCost_ATB_18MW_2030_Transmission_1000MW.npz")
SolutionPath.append(MainPortResultsPath+"Wind_BOEM_Upscale24h_0.02Degree_GenCost_ATB_18MW_2030_Transmission_600MW.npz")


Legend=[] #one list per solution, each list contains the legend for each design of each technology 3d list
Legend.append( [["Wind 18MW- TL 1.2GW"],
                [],
                []])

Legend.append( [["Wind 18MW- TL 1.0GW"],
                [],
                []])

Legend.append( [["Wind 18MW- TL 0.6GW"],
                [],
                []])

LCOE_Target=-1 #Lowest LCOE
StateCountours="./InputData/CoastLine/"
LatMaxMin=(33.3, 37.2)
LongMaxMin=(-78.7, -74.3)

PathDataUnderLayer=[]
PathDataUnderLayer.append("./OutputData/Wind/BOEM_Upscale24h_0.02Degree_GenCost_ATB_18MW_2030.npz")
LegendUnderLayerColorbar=["Wind [pu]"]

SavePath="./OutputData/Plots/Portfolios/WindOnly/BOEM_WindOnly_Locations_MinLCOE_18MWTurbine.png"
PlotTurbineLocations(SolutionPath, Legend, PathDataUnderLayer, LegendUnderLayerColorbar, StateCountours,LCOE_Target=-1, LatMaxMin=(33.3, 37.2), LongMaxMin=(-78.7, -74.3), SavePath=SavePath)

# %%
MainPortResultsPath="./OutputData/Portfolios/"
SolutionPath=[]
SolutionPath.append(MainPortResultsPath+"Wind_BOEM_Upscale24h_0.02Degree_GenCost_ATB_8MW_2020_Vestas_Transmission_1200MW.npz")
SolutionPath.append(MainPortResultsPath+"Wind_BOEM_Upscale24h_0.02Degree_GenCost_ATB_8MW_2020_Vestas_Transmission_1000MW.npz")
SolutionPath.append(MainPortResultsPath+"Wind_BOEM_Upscale24h_0.02Degree_GenCost_ATB_8MW_2020_Vestas_Transmission_600MW.npz")


Legend=[] #one list per solution, each list contains the legend for each design of each technology 3d list
Legend.append( [["Wind 8MW- TL 1.2GW"],
                [],
                []])

Legend.append( [["Wind 8MW- TL 1.0GW"],
                [],
                []])

Legend.append( [["Wind 8MW- TL 0.6GW"],
                [],
                []])

LCOE_Target=-1 #Lowest LCOE
StateCountours="./InputData/CoastLine/"
LatMaxMin=(33.3, 37.2)
LongMaxMin=(-78.7, -74.3)

PathDataUnderLayer=[]
PathDataUnderLayer.append("./OutputData/Wind/BOEM_Upscale24h_0.02Degree_GenCost_ATB_8MW_2020_Vestas.npz")
LegendUnderLayerColorbar=["Wind [pu]"]

SavePath="./OutputData/Plots/Portfolios/WindOnly/BOEM_WindOnly_Locations_MinLCOE_8MWTurbine.png"
PlotTurbineLocations(SolutionPath, Legend, PathDataUnderLayer, LegendUnderLayerColorbar, StateCountours,LCOE_Target=-1, LatMaxMin=(33.3, 37.2), LongMaxMin=(-78.7, -74.3), SavePath=SavePath)

# %% [markdown]
# # Wind Only All Sites

# %%
SolutionPaths=[]
MainPortResultsPath="./OutputData/Portfolios/"

#1.2GW Transmission
SolutionPaths.append(MainPortResultsPath+"Wind_Upscale24h_0.05Degree_GenCost_ATB_8MW_2020_Vestas_Transmission_1200MW.npz")
SolutionPaths.append(MainPortResultsPath+"Wind_Upscale24h_0.05Degree_GenCost_ATB_12MW_2030_Transmission_1200MW.npz")
SolutionPaths.append(MainPortResultsPath+"Wind_Upscale24h_0.05Degree_GenCost_ATB_15MW_2030_Transmission_1200MW.npz")
SolutionPaths.append(MainPortResultsPath+"Wind_Upscale24h_0.05Degree_GenCost_ATB_18MW_2030_Transmission_1200MW.npz")

#1.0GW Transmission
SolutionPaths.append(MainPortResultsPath+"Wind_Upscale24h_0.05Degree_GenCost_ATB_8MW_2020_Vestas_Transmission_1000MW.npz")
SolutionPaths.append(MainPortResultsPath+"Wind_Upscale24h_0.05Degree_GenCost_ATB_12MW_2030_Transmission_1000MW.npz")
SolutionPaths.append(MainPortResultsPath+"Wind_Upscale24h_0.05Degree_GenCost_ATB_15MW_2030_Transmission_1000MW.npz")
SolutionPaths.append(MainPortResultsPath+"Wind_Upscale24h_0.05Degree_GenCost_ATB_18MW_2030_Transmission_1000MW.npz")

#0.6GW Transmission
SolutionPaths.append(MainPortResultsPath+"Wind_Upscale24h_0.05Degree_GenCost_ATB_8MW_2020_Vestas_Transmission_600MW.npz")
SolutionPaths.append(MainPortResultsPath+"Wind_Upscale24h_0.05Degree_GenCost_ATB_12MW_2030_Transmission_600MW.npz")
SolutionPaths.append(MainPortResultsPath+"Wind_Upscale24h_0.05Degree_GenCost_ATB_15MW_2030_Transmission_600MW.npz")
SolutionPaths.append(MainPortResultsPath+"Wind_Upscale24h_0.05Degree_GenCost_ATB_18MW_2030_Transmission_600MW.npz")

# #0.3GW Transmission
SolutionPaths.append(MainPortResultsPath+"Wind_Upscale24h_0.05Degree_GenCost_ATB_8MW_2020_Vestas_Transmission_300MW.npz")
SolutionPaths.append(MainPortResultsPath+"Wind_Upscale24h_0.05Degree_GenCost_ATB_12MW_2030_Transmission_300MW.npz")
SolutionPaths.append(MainPortResultsPath+"Wind_Upscale24h_0.05Degree_GenCost_ATB_15MW_2030_Transmission_300MW.npz")
SolutionPaths.append(MainPortResultsPath+"Wind_Upscale24h_0.05Degree_GenCost_ATB_18MW_2030_Transmission_300MW.npz")

Legend=["1.2GW TL - 8MW WT","1.2GW TL - 12MW WT","1.2GW TL - 15MW WT","1.2GW TL - 18MW WT",
        "1.0GW TL - 8MW WT","1.0GW TL - 12MW WT","1.0GW TL - 15MW WT","1.0GW TL - 18MW WT",
        "0.6GW TL - 8MW WT","0.6GW TL - 12MW WT","0.6GW TL - 15MW WT","0.6GW TL - 18MW WT",
        "0.3GW TL - 8MW WT","0.3GW TL - 12MW WT","0.3GW TL - 15MW WT","0.3GW TL - 18MW WT"]

Title="Wind BOEM portfolios"

SavePath="./OutputData/Plots/Portfolios/WindOnly/WindOnlyAllSites_EfficientFrontier.png"
PlotEfficientFrontier(SolutionPaths, Legend, Title, SavePath=SavePath)

# %%
MainPortResultsPath="./OutputData/Portfolios/"
SolutionPath=[]
SolutionPath.append(MainPortResultsPath+"Wind_Upscale24h_0.05Degree_GenCost_ATB_18MW_2030_Transmission_1200MW.npz")
SolutionPath.append(MainPortResultsPath+"Wind_Upscale24h_0.05Degree_GenCost_ATB_18MW_2030_Transmission_1000MW.npz")
SolutionPath.append(MainPortResultsPath+"Wind_Upscale24h_0.05Degree_GenCost_ATB_18MW_2030_Transmission_600MW.npz")


Legend=[] #one list per solution, each list contains the legend for each design of each technology 3d list
Legend.append( [["Wind 18MW- TL 1.2GW"],
                [],
                []])

Legend.append( [["Wind 18MW- TL 1.0GW"],
                [],
                []])

Legend.append( [["Wind 18MW- TL 0.6GW"],
                [],
                []])

LCOE_Target=-1 #Lowest LCOE
StateCountours="./InputData/CoastLine/"
LatMaxMin=(33.3, 37.2)
LongMaxMin=(-78.7, -74.3)

PathDataUnderLayer=[]
PathDataUnderLayer.append("./OutputData/Wind/Upscale24h_0.05Degree_GenCost_ATB_18MW_2030.npz")
LegendUnderLayerColorbar=["Wind [pu]"]

SavePath="./OutputData/Plots/Portfolios/WindOnly/WindOnly_Locations_MinLCOE_18MWTurbine.png"
PlotTurbineLocations(SolutionPath, Legend, PathDataUnderLayer, LegendUnderLayerColorbar, StateCountours,LCOE_Target=-1, LatMaxMin=(33.3, 37.2), LongMaxMin=(-78.7, -74.3), SavePath=SavePath)

# %%
MainPortResultsPath="./OutputData/Portfolios/"
SolutionPath=[]
SolutionPath.append(MainPortResultsPath+"Wind_Upscale24h_0.05Degree_GenCost_ATB_8MW_2020_Vestas_Transmission_1200MW.npz")
SolutionPath.append(MainPortResultsPath+"Wind_Upscale24h_0.05Degree_GenCost_ATB_8MW_2020_Vestas_Transmission_1000MW.npz")
SolutionPath.append(MainPortResultsPath+"Wind_Upscale24h_0.05Degree_GenCost_ATB_8MW_2020_Vestas_Transmission_600MW.npz")


Legend=[] #one list per solution, each list contains the legend for each design of each technology 3d list
Legend.append( [["Wind 8MW- TL 1.2GW"],
                [],
                []])

Legend.append( [["Wind 8MW- TL 1.0GW"],
                [],
                []])

Legend.append( [["Wind 8MW- TL 0.6GW"],
                [],
                []])

LCOE_Target=-1 #Lowest LCOE
StateCountours="./InputData/CoastLine/"
LatMaxMin=(33.3, 37.2)
LongMaxMin=(-78.7, -74.3)

PathDataUnderLayer=[]
PathDataUnderLayer.append("./OutputData/Wind/Upscale24h_0.05Degree_GenCost_ATB_8MW_2020_Vestas.npz")
LegendUnderLayerColorbar=["Wind [pu]"]

SavePath="./OutputData/Plots/Portfolios/WindOnly/WindOnly_Locations_MinLCOE_8MWTurbine.png"
PlotTurbineLocations(SolutionPath, Legend, PathDataUnderLayer, LegendUnderLayerColorbar, StateCountours,LCOE_Target=-1, LatMaxMin=(33.3, 37.2), LongMaxMin=(-78.7, -74.3), SavePath=SavePath)

# %% [markdown]
# # Template for Plots With All Technologies

# %%
LCOE_Target=-1 #Lowest LCOE

MainPortResultsPath="./OutputData/Portfolios/"

SolutionPath=[]
# SolutionPath.append(MainPortResultsPath+"Wind_Upscale24h_0.05Degree_GenCost_ATB_8MW_2020_Vestas_Transmission_1200MW.npz")
# SolutionPath.append(MainPortResultsPath+"Wind_Upscale24h_0.05Degree_GenCost_ATB_12MW_2030_Transmission_1200MW.npz")
# SolutionPath.append(MainPortResultsPath+"Wind_Upscale24h_0.05Degree_GenCost_ATB_15MW_2030_Transmission_1200MW.npz")
SolutionPath.append(MainPortResultsPath+"Wind_Wave_OF_Delete.npz")

Legend=[] #one list per solution, each list contains the legend for each design of each technology 3d list
Legend.append([["Wind D1", "Wind D2", "Wind D3", "Wind D4"],
                ["Wave D1", "Wave D2", "Wave D3", "Wave D4"],
                ["Kite D1", "Kite D2", "Kite D3", "Kite D4"]])

Legend.append([["Wind D1", "Wind D2", "Wind D3", "Wind D4"],
                ["Wave D1", "Wave D2", "Wave D3", "Wave D4"],
                ["Kite D1", "Kite D2", "Kite D3", "Kite D4"]])

StateCountours="./InputData/CoastLine/"
LatMaxMin=(33.3, 37.2)
LongMaxMin=(-78.7, -74.3)

PathDataUnderLayer=[]
PathDataUnderLayer.append("./OutputData/Wind/GenCost_ATB_18MW_2030.npz")
PathDataUnderLayer.append("./OutputData/Wind/BOEM_Upscale24h_0.1Degree_GenCost_ATB_8MW_2020_Vestas.npz")
LegendUnderLayerColorbar=["Wind [pu]","Wave [pu]", "Ocean Current [pu]"]

SavePath=None
PlotTurbineLocations(SolutionPath, Legend, PathDataUnderLayer, LegendUnderLayerColorbar, StateCountours,LCOE_Target=-1, LatMaxMin=(33.3, 37.2), LongMaxMin=(-78.7, -74.3), SavePath=SavePath)

# %% [markdown]
# # Plot Wind Kite

# %%
SolutionPaths=[]
MainPortResultsPath="./OutputData/Portfolios/"

#1.2GW Transmission
SolutionPaths.append(MainPortResultsPath+"Wind18MW_4KiteDesings_1200MW.npz")
SolutionPaths.append(MainPortResultsPath+"Wind18MWBOEM_4KiteDesings_1200MW.npz")


Legend=["1.2GW TL - 18MW WT All Sites","1.2GW TL - 18MW WT BOEM Sites"]

Title="Wind-Kite Portfolios"

SavePath="./OutputData/Plots/Portfolios/WindOnly/WindKite_EfficientFrontier.png"
PlotEfficientFrontier(SolutionPaths, Legend, Title, SavePath=SavePath)

# %%
PlotPowerTechDistribution(SolutionPaths[0], SavePath=None)
PlotPowerTechDistribution(SolutionPaths[1], SavePath=None)
PlotPowerTechDistribution("./OutputData/Portfolios/Wind18MW_0KiteDesings_1200MW.npz", SavePath=None)
PlotPowerTechDistribution("./OutputData/Portfolios/Wind18MWBOEM_0KiteDesings_1200MW.npz", SavePath=None)

# %%
LCOE_Target=-1 #Lowest LCOE

MainPortResultsPath="./OutputData/Portfolios/"

SolutionPath=[]
# SolutionPath.append(MainPortResultsPath+"Wind_Upscale24h_0.05Degree_GenCost_ATB_8MW_2020_Vestas_Transmission_1200MW.npz")
# SolutionPath.append(MainPortResultsPath+"Wind_Upscale24h_0.05Degree_GenCost_ATB_12MW_2030_Transmission_1200MW.npz")
# SolutionPath.append(MainPortResultsPath+"Wind_Upscale24h_0.05Degree_GenCost_ATB_15MW_2030_Transmission_1200MW.npz")
SolutionPath.append(MainPortResultsPath+"Wind18MW_4KiteDesings_1200MW.npz")


Legend=[] #one list per solution, each list contains the legend for each design of each technology 3d list
Legend.append([["Wind D1", "Wind D2", "Wind D3", "Wind D4"],
                ["Wave D1", "Wave D2", "Wave D3", "Wave D4"],
                ["Kite D1", "Kite D2", "Kite D3", "Kite D4"]])

Legend.append([["Wind D1", "Wind D2", "Wind D3", "Wind D4"],
                ["Wave D1", "Wave D2", "Wave D3", "Wave D4"],
                ["Kite D1", "Kite D2", "Kite D3", "Kite D4"]])

StateCountours="./InputData/CoastLine/"
LatMaxMin=(33.3, 37.2)
LongMaxMin=(-78.7, -74.3)

PathDataUnderLayer=[]
GeneralPathResources="./OutputData/"


PathDataUnderLayer.append("./OutputData/Wind/Upscale24h_0.07Degree_2007GenCost_ATB_18MW_2030.npz")
PathDataUnderLayer.append("./OutputData/OceanCurrent/PowerTimeSeriesKite_VD50_BCS2.5.npz")
UnderLayerVariable=["RawResource", "RawResource"]
LegendUnderLayerColorbar=["Wind Speed \n[m/s]", "OC Speed\n [m/s]"]

SavePath=None
PlotTurbineLocations(SolutionPath, Legend, PathDataUnderLayer, LegendUnderLayerColorbar, StateCountours, UnderLayerVariable,LCOE_Target=-1, LatMaxMin=(33.3, 37.2), LongMaxMin=(-78.7, -74.3), SavePath=SavePath)

# %%
LCOE_Target=130 #Lowest LCOE

MainPortResultsPath="./OutputData/Portfolios/"

SolutionPath=[]
# SolutionPath.append(MainPortResultsPath+"Wind_Upscale24h_0.05Degree_GenCost_ATB_8MW_2020_Vestas_Transmission_1200MW.npz")
# SolutionPath.append(MainPortResultsPath+"Wind_Upscale24h_0.05Degree_GenCost_ATB_12MW_2030_Transmission_1200MW.npz")
# SolutionPath.append(MainPortResultsPath+"Wind_Upscale24h_0.05Degree_GenCost_ATB_15MW_2030_Transmission_1200MW.npz")
SolutionPath.append(MainPortResultsPath+"Wind18MWBOEM_4KiteDesings_1200MW.npz")


Legend=[] #one list per solution, each list contains the legend for each design of each technology 3d list
Legend.append([["Wind D1", "Wind D2", "Wind D3", "Wind D4"],
                ["Wave D1", "Wave D2", "Wave D3", "Wave D4"],
                ["Kite D1", "Kite D2", "Kite D3", "Kite D4"]])

Legend.append([["Wind D1", "Wind D2", "Wind D3", "Wind D4"],
                ["Wave D1", "Wave D2", "Wave D3", "Wave D4"],
                ["Kite D1", "Kite D2", "Kite D3", "Kite D4"]])

StateCountours="./InputData/CoastLine/"
LatMaxMin=(33.3, 37.2)
LongMaxMin=(-78.7, -74.3)

PathDataUnderLayer=[]
GeneralPathResources="./OutputData/"


PathDataUnderLayer.append("./OutputData/Wind/BOEM_2007_Upscale24h_0.02Degree_GenCost_ATB_18MW_2030.npz")
PathDataUnderLayer.append("./OutputData/OceanCurrent/PowerTimeSeriesKite_VD50_BCS2.5.npz")
UnderLayerVariable=["RawResource", "RawResource"]
LegendUnderLayerColorbar=["Wind Speed \n[m/s]", "OC Speed\n [m/s]"]

SavePath=None
PlotTurbineLocations(SolutionPath, Legend, PathDataUnderLayer, LegendUnderLayerColorbar, StateCountours, UnderLayerVariable,LCOE_Target=LCOE_Target, LatMaxMin=(33.3, 37.2), LongMaxMin=(-78.7, -74.3), SavePath=SavePath)
