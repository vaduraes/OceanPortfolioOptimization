# %%
# #Download significant wave height and wave period from Wave watch III model
from dateutil.relativedelta import relativedelta
import datetime as dt
import sys
sys.path.append('./Tools')
from DownloadWWIII_Wave import DonwloadWave_WWIII



# #Download significant wave height and wave period from Wave watch III model
FromDate=dt.date(2005, 7, 1) #Older data are not available #FromDate=dt.date(2005, 2, 1)
ToDate=dt.date(2019, 1, 1)
SavePath="./InputData/Wave/WWIII/"

DonwloadWave_WWIII(FromDate, ToDate, SavePath)
# Out:
# ---- File multi_1.at_4m.tp.200507.grb2 already exists, skipping
# ---- File multi_1.at_4m.hs.200507.grb2 already exists, skipping
# ---- Year 2005 /Month 07 Done,    Percentage Complete 0.0
# ---- File multi_1.at_4m.tp.200508.grb2 already exists, skipping
# ---- File multi_1.at_4m.hs.200508.grb2 already exists, skipping
# ---- Year 2005 /Month 08 Done,    Percentage Complete 0.628420839245895
# ---- File multi_1.at_4m.tp.200509.grb2 already exists, skipping
# ---- File multi_1.at_4m.hs.200509.grb2 already exists, skipping
# ---- Year 2005 /Month 09 Done,    Percentage Complete 1.25684167849179
# ---- File multi_1.at_4m.tp.200510.grb2 already exists, skipping
# ---- File multi_1.at_4m.hs.200510.grb2 already exists, skipping
# ---- Year 2005 /Month 10 Done,    Percentage Complete 1.864990877762011
# ---- File multi_1.at_4m.tp.200511.grb2 already exists, skipping
# ---- File multi_1.at_4m.hs.200511.grb2 already exists, skipping
# ...
